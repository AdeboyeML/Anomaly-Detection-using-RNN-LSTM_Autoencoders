# %% [markdown]
# ## Using the Automated Method created to pinpoint times of fault and failures (i.e. anomalies) in machines.

# %%
from automated import automated_method
# Out:
# Using TensorFlow backend.

# %%
def main():
    
    input_data = 'machine_1.csv' #Input data should be in CSV format
    window = 25                  #Window size for the Moving Window Average
    split_size = 0.75            #Split size should be between 0.00 and 1.00
    time_steps = 21              #Time steps for the LSTM Sequence
    learning_rate = 0.0001       #learning rate
    epoch = 200                  #Number of epochs
    batch_size = 64              #Batch size
    
    df_machine = automated_method(input_data, window, split_size, time_steps, learning_rate, epoch, batch_size)

if __name__ == "__main__":
    main()
# Out:
# Train on 2006 samples, validate on 223 samples
# Epoch 1/200
# 2006/2006 [==============================] - 2s 1ms/step - loss: 0.9762 - val_loss: 0.9545
# Epoch 2/200
# 2006/2006 [==============================] - 1s 567us/step - loss: 0.9731 - val_loss: 0.9512
# Epoch 3/200
# 2006/2006 [==============================] - 1s 579us/step - loss: 0.9697 - val_loss: 0.9473
# Epoch 4/200
# 2006/2006 [==============================] - 1s 581us/step - loss: 0.9656 - val_loss: 0.9423
# Epoch 5/200
# 2006/2006 [==============================] - 1s 590us/step - loss: 0.9601 - val_loss: 0.9352
# Epoch 6/200
# 2006/2006 [==============================] - 1s 596us/step - loss: 0.9520 - val_loss: 0.9248
# Epoch 7/200
# 2006/2006 [==============================] - 1s 601us/step - loss: 0.9384 - val_loss: 0.9076
# Epoch 8/200
# 2006/2006 [==============================] - 1s 583us/step - loss: 0.9199 - val_loss: 0.8821
# Epoch 9/200
# ...
